# %%
import streamlit as st
import pandas as pd
import pickle

with open("fraud_model.pkl", "rb") as f:
    model = pickle.load(f)

with open("scaler.pkl", "rb") as f:
    scaler = pickle.load(f)

st.set_page_config(
    page_title="Credit Card Fraud Detection",
    layout="centered"
)

st.title("💳 Credit Card Fraud Detection")
st.write(
    "This app predicts whether a transaction is **Fraud** or **Legit** "
    "based on a trained Machine Learning model."
)

st.divider()


st.subheader("Enter Transaction Details")


time = st.number_input(
    "Time (seconds since first transaction)",
    min_value=0.0,
    value=100000.0
)

amount = st.number_input(
    "Transaction Amount",
    min_value=0.0,
    value=100.0
)



input_data = {
    "Time": time,
    "Amount": amount
}


for i in range(1, 29):
    input_data[f"V{i}"] = 0.0


df = pd.DataFrame([input_data])


if st.button("Predict Fraud"):

    
    df[["Time", "Amount"]] = scaler.transform(df[["Time", "Amount"]])

 
    fraud_probability = model.predict_proba(df)[:, 1][0]

    
    threshold = 0.8

    if fraud_probability >= threshold:
        prediction = "Fraud 🚨"
        st.error(prediction)
    else:
        prediction = "Legit ✅"
        st.success(prediction)

    st.subheader("Prediction Result")
    st.write(f"**Fraud Probability:** {fraud_probability:.4f}")
# Out:
# 2026-01-20 19:07:22.069 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.070 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.694
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\SARAN\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-01-20 19:07:22.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.706 Session state does not function when running a script without `streamlit run`
# 2026-01-20 19:07:22.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.711 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-20 19:07:22.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
